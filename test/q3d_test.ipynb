# %%
import sys
sys.path.append('..')

from renderer.q3d.capative import capacitance
import os
gds_name = 'QRT.gds'

base_dir = os.getcwd()  # 当前工作目录
gds_path = os.path.join(base_dir, gds_name)

ei = capacitance(project = 'project' , version = '2024.1')

ei.run_q3d_extraction_from_gds(gds_name)
# Out:
# PyAEDT INFO: Python version 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)].
# PyAEDT INFO: PyAEDT version 0.18.1.
# PyAEDT INFO: Initializing new Desktop session.
# PyAEDT INFO: Log on console is enabled.
# PyAEDT INFO: Log on file C:\Users\chen\AppData\Local\Temp\pyaedt_chen_6361785f-5f0b-48fa-ab9a-630743080ea7.log is enabled.
# PyAEDT INFO: Log on AEDT is disabled.
# PyAEDT INFO: Debug logger is disabled. PyAEDT methods will not be logged.
# PyAEDT INFO: Launching PyAEDT with gRPC plugin.
# d:\anaconda3\envs\qeda_env\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# PyAEDT INFO: New AEDT session is starting on gRPC port 52955.
# PyAEDT INFO: Electronics Desktop started on gRPC port: 52955 after 6.922586679458618 seconds.
# PyAEDT INFO: AEDT installation Path D:\Program Files\AnsysEM\v241\Win64
# ...
